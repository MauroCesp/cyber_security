# %% [markdown]
# Lo primero que hay que hacer es installar un laboratorio.
#
# Primero installamaos nua maquina virtual con VirtualBox

# %% [markdown]
# https://www.virtualbox.org/wiki/Downloads

# %% [markdown]
# Todo esto lo vamos a hacer utilizando Kali.
#
# Descargamos kali que ya vienen preparado para maquinas virtuales.
#
# https://www.kali.org/get-kali/#kali-virtual-machines

# %%
from IPython.display import Image
Image(filename='img/1.PNG')

# %%
from IPython.display import Image
Image(filename='img/2.PNG')

# %% [markdown]
# Ahora regresamos a la parte de Virtual Box y le damos añadir

# %%
from IPython.display import Image
Image(filename='img/3.PNG')

# %%
Necesito agregar el archivo con la extension correcta porque tengo varios archivos.

Necesito installar el **VDI**
