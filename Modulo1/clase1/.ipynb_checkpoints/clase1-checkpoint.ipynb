# %% [markdown]
# ## Configuracion del entorno

# %% [markdown]
# Lo primero que hay que hacer es installar un laboratorio.
#
# Primero installamaos nua maquina virtual con VirtualBox

# %% [markdown]
# https://www.virtualbox.org/wiki/Downloads

# %% [markdown]
# Todo esto lo vamos a hacer utilizando Kali.
#
# Descargamos kali que ya vienen preparado para maquinas virtuales.
#
# https://www.kali.org/get-kali/#kali-virtual-machines

# %%
from IPython.display import Image
Image(filename='img/1.PNG')

# %%
from IPython.display import Image
Image(filename='img/2.PNG')

# %% [markdown]
# Ahora regresamos a la parte de Virtual Box y le damos añadir

# %%
from IPython.display import Image
Image(filename='img/3.PNG')

# %% [markdown]
# Necesito agregar el archivo con la extension correcta porque tengo varios archivos.
#
# Necesito installar el **VDI**

# %%
from IPython.display import Image
Image(filename='img/4.PNG')

# %%
from IPython.display import Image
Image(filename='img/5.PNG')

# %% [markdown]
# Default password and username Kali
# Una vez que tengamos Kali installado abro la terminal y compruebo que esta installado lo siguiente:
#
#     python -V ------- Version de python
#     nmap ------------Herramienta Nmapmsfcosole
#     msfconsole-------------- La cosola de metaexploit
#
# Ahora vamos a installar visual studio que es el Idle con el que trabajamos.
#
# https://code.visualstudio.com/Download
#
# Escojemos la opcion para debian
#
#    Una vez descargado desde la terminal vamos a a dwonloads y hacemos un sudo apt install -----

# %%
from IPython.display import Image
Image(filename='img/6.PNG')

# %% [markdown]
# Si sale un error es porque tenemos que darle permisos de administrador a la carpeta de downloads.
#
# sudo su
#
# Una vez que lo installamos podemos ver visual studio code.

# %% [markdown]
# Despues vamos a ir a la parte de **KEYBOARD**
#
# Aqui podemos cambiar el idioma del tecaldo

# %%
from IPython.display import Image
Image(filename='img/7.PNG')

# %% [markdown]
# ### COnfiguracion maquina virtual

# %% [markdown]
# Realizo una conexion Bridge que permite connectar maquina Windows con la maquina virtual

# %% [markdown]
# Es ese caso ser{ia asi:
#                }
#     Configuracion>Networks>Adapter1
#
# Configuramos el adaptador 1 como **Bridge**

# %% [markdown]
# ### Compruebo IP
#
# ifconfig de esta manera podemos comunicarnos con la maquina anfitriona.

# %% [markdown]
# ## Recoleccion de informacion

# %% [markdown]
# Es necesario tomar encuenta la informacion que podemos conseguir de insternet.
# Pero es necesario saber **filtrar**
#
# Si es un atacante necesita saber que informacion es importante sobre el sistema objetivo que se va a atacar.

# %%
from IPython.display import Image
Image(filename='img/100.png')

# %% [markdown]
# Es importante si subsanan una vulnerabiliida de l sistema objetivo asegurarnos de dejar un backdoor para garantizar accesso en el futuro

# %% [markdown]
# Python tiene una gran variedad de librerias que nos permiten hacer esta recoleccion informacion inicial, de manera pasiva como activa

# %% [markdown]
# EL numero de gente que se conecta al internet aumenta, tambien la informacion  publica en la nube.
#
# Asi tambien com ola cantidad de informacion veraz, falta o a medias.
#
#
# **OSINT** -----> Open Source Inteligence
#
# Existe un marco de trabajo para esto que se llama OSINT FrameWork
# https://osintframework.com/
#
# Es muy popular porque esta muy organizado.
#
# NO tienen una interfaz grafica para utilizar sus potencialidad, pero si se puede integrar con solucines que cualquiera puede desarrollar.

# %% [markdown]
# #### Consultas WHOIS

# %%
from IPython.display import Image
Image(filename='img/101.png')

# %% [markdown]
# Al gunos ofrecedores de dominio vende un **registro** privado que se conoce como servicios proxy.
#
# Es como un puente donde se muestra la info de contacto de registrador y no la del registrante.
#
# La organizacion que ofrece el servicio es el registrador y el contacto.
#
# Las autoridades pueden exigir los datos reales de los registradores del dominio. Por ley tienen que revelar la informacion privada.

# %% [markdown]
# Lo primero es installar la libreria de whois
#
# - python -m pip install python-whois

# %% [markdown]
# Es resto de la infromacion sobre el script esta en github
