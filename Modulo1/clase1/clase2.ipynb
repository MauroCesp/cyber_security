# %% [markdown]
# ## CONSULTA DNS

# %%
from IPython.display import Image
Image(filename='img/200.png')

# %% [markdown]
# Es un protocolo de texto basado en UDP
#
# UN servidor DNS es un sistema con una base de datos con la IP publicas asociadas a los sitios web, a los que una direccion IP lleva a una usuarios
#
# COmo una agenda telefonica de IPs
#
# Cunado se escribe el nombre del dominio el DNS encuentra la direccion correcta para enviar el dispositivo al cliente correcto

# %% [markdown]
# EL DNS resolver recibe la URL del sitio web y recupera la direccion que va con esa URL.

# %% [markdown]
# Lo vamos a ver con el script.

# %% [markdown]
# ## SHODAN

# %% [markdown]
# Es un motor de busqueda como google o bind
#
# Pero en lugar de indexar los contenidos como hace **Yandex** los que hace es indexar las cabeceras y los banner devueltos por estos servicios
#
# Se aplican filtros para buscar servidores que tengan una tecnologia concreta o un protocolo caoncreto

# %% [markdown]
# Para poder utilizarlo necesitamos abrir una cuenta  y obtener una shodan KEY
#
# Sino se piensa utilizar en el futuro se recomienda realizar el registro con una cuenta de tempmail
#
# **TEMP MAIL** Es un servicio de correo electronico temporal
#
# https://temp-mail.org/es/
#
# Lo utilizamos para crea una cuenta temporal de SHODAN
# Ahi recibimos el correo de confirmacion

# %% [markdown]
# https://www.shodan.io/
#
# En Shodan en **Account** vamos a tener el API key que utilizamos en los scripts
#
# Esta es un herramieta interesante para filtrar hasta llegar al target.
#
# Por ejemplo tenemos una empresa en Espña que sabemos utlizan servidores ftp
#
# Utilizo **ftp** para definir lo que quiero buscar
#
# **Country** me dice en donde buscar
#
# **Product** el tipo de producto que la empresa que busco fabrica o la marca

# %%
from IPython.display import Image
Image(filename='img/301.png')

# %% [markdown]
# Cuando corremos el script y conectamos con el shoda API obtenemos el estado de nuestra ceunta, deice si tenemos queditos etcetera

# %%
from IPython.display import Image
Image(filename='img/305.png')
